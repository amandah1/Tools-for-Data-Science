# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:56418449-4b06-4dab-8f85-fedd41db6993.png)

# %% [markdown]
# ---In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:b84cfb1d-e7b5-4bf5-b97f-ffc6618db8a3.png)

# %% [markdown]
# ---Some of the popular languages that Data Scientists use are:
# 1. Python
# 1. R
# 1. C++
# 1. MATLAB
# 1. SAS

# %% [markdown]
# ![4-dslanguages.png](attachment:bf82bba4-1795-4d5f-b930-a3db76ba1d88.png)

# %% [markdown]
# ---Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Keras
# 4. TensorFlow
# 5. SciPy
# 6. Matplotlib

# %% [markdown]
# ![5-dslibraries.png](attachment:79663b87-c2ff-4be0-be3b-86a35acadf60.png)

# %% [markdown]
# | Data Science Tools |
# | Git |
# | Apache Kafka |
# | RStudio|

# %% [markdown]
# ![6-dstools.png](attachment:d6fa84c9-e2f3-44f6-90b7-4aa5541bf5e0.png)

# %%
### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:0c8b09bb-8121-46a4-951b-53a3e005d445.png)

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:460b6aa1-c163-4d1c-99d9-9573a3d14441.png)

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:dcb84ada-e222-4788-a829-5512c8059490.png)

# %% [markdown]
# # **Objectives**
# - List popular languages for Data Science
# - List commonly used libraries for Data Science
# - List popular development environment open source tools for Data Science
# - Identify syntax and formatting differences between code cells and Markdown cells

# %% [markdown]
# ![10-objectives.png](attachment:e8dd8711-55bf-4ab8-829e-b27a24cf9060.png)

# %% [markdown]
# ## Author
# Amanda Hoang

# %% [markdown]
# ![11-authordetails.png](attachment:524b4b2d-1f75-42de-8c19-348081a8818d.png)

# %% [markdown]
# ![1-notebook.png](attachment:ee206012-1a89-4104-b10c-87eb530198d2.png)
